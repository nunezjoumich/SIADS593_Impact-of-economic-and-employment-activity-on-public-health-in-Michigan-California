# %% [markdown]
# # 📓 Manual State-Level County Employment Dataset (BLS LAUS)
#
# This notebook demonstrates how to build a **county-level dataset** for a single state (e.g., California) using BLS Local Area Unemployment Statistics (LAUS) files.
#
# You can change the state FIPS code and data file at the top to process a different state.

# %%
# --- 1. Config ---
STATE_FIPS = "26"  # California
DATA_FILE = "la.data.29.Michigan"  # California LAUS data file
# Example: set STATE_FIPS = "26", DATA_FILE = "la.data.29.Michigan" for Michigan
# Out:
# Requirement already satisfied: pandas in /Users/benjaminstrelzoff/miniconda3/envs/BHR-CMI/lib/python3.13/site-packages (2.3.3)
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
# --- 1. Config ---
# Define FIPS codes and data file names manually
STATE_CONFIGS = [
    {"fips": "01", "file": "la.data.7.Alabama"},
    {"fips": "02", "file": "la.data.8.Alaska"},
    {"fips": "04", "file": "la.data.9.Arizona"},
    {"fips": "05", "file": "la.data.10.Arkansas"},
    {"fips": "06", "file": "la.data.11.California"},
    {"fips": "08", "file": "la.data.12.Colorado"},
    {"fips": "09", "file": "la.data.13.Connecticut"},
    {"fips": "10", "file": "la.data.14.Delaware"},
    {"fips": "11", "file": "la.data.15.DC"},
    {"fips": "12", "file": "la.data.16.Florida"},
    {"fips": "13", "file": "la.data.17.Georgia"},
    {"fips": "15", "file": "la.data.18.Hawaii"},
    {"fips": "16", "file": "la.data.19.Idaho"},
    {"fips": "17", "file": "la.data.20.Illinois"},
    {"fips": "18", "file": "la.data.21.Indiana"},
    {"fips": "19", "file": "la.data.22.Iowa"},
    {"fips": "20", "file": "la.data.23.Kansas"},
    {"fips": "21", "file": "la.data.24.Kentucky"},
    {"fips": "22", "file": "la.data.25.Louisiana"},
    {"fips": "23", "file": "la.data.26.Maine"},
    {"fips": "24", "file": "la.data.27.Maryland"},
    {"fips": "25", "file": "la.data.28.Massachusetts"},
    {"fips": "26", "file": "la.data.29.Michigan"},
    {"fips": "27", "file": "la.data.30.Minnesota"},
    {"fips": "28", "file": "la.data.31.Mississippi"},
    {"fips": "29", "file": "la.data.32.Missouri"},
    {"fips": "30", "file": "la.data.33.Montana"},
    {"fips": "31", "file": "la.data.34.Nebraska"},
    {"fips": "32", "file": "la.data.35.Nevada"},
    {"fips": "33", "file": "la.data.36.NewHampshire"},
    {"fips": "34", "file": "la.data.37.NewJersey"},
    {"fips": "35", "file": "la.data.38.NewMexico"},
    {"fips": "36", "file": "la.data.39.NewYork"},
    {"fips": "37", "file": "la.data.40.NorthCarolina"},
    {"fips": "38", "file": "la.data.41.NorthDakota"},
    {"fips": "39", "file": "la.data.42.Ohio"},
    {"fips": "40", "file": "la.data.43.Oklahoma"},
    {"fips": "41", "file": "la.data.44.Oregon"},
    {"fips": "42", "file": "la.data.45.Pennsylvania"},
    {"fips": "44", "file": "la.data.47.RhodeIsland"},
    {"fips": "45", "file": "la.data.48.SouthCarolina"},
    {"fips": "46", "file": "la.data.49.SouthDakota"},
    {"fips": "47", "file": "la.data.50.Tennessee"},
    {"fips": "48", "file": "la.data.51.Texas"},
    {"fips": "49", "file": "la.data.52.Utah"},
    {"fips": "50", "file": "la.data.53.Vermont"},
    {"fips": "51", "file": "la.data.54.Virginia"},
    {"fips": "53", "file": "la.data.56.Washington"},
    {"fips": "55", "file": "la.data.58.Wisconsin"},
    {"fips": "56", "file": "la.data.59.Wyoming"},
]

# %%
# # --- 2. Setup ---
# import pandas as pd

# # Load lookup files
# la_area = pd.read_csv("la.area", sep="\t", dtype=str)
# la_area_type = pd.read_csv("la.area_type", sep="\t", dtype=str)

# la_series = pd.read_csv(
#     "la.series", 
#     sep="\t", header=None,
#     names=[
#         "series_id","area_type_code","area_code",
#         "measure_code","seasonal","srd_code",
#         "series_title","footnote_codes",
#         "begin_year","begin_period",
#         "end_year","end_period"
#     ],
#     dtype=str
# )

# print("Lookup files loaded.")

# %%
import pandas as pd
import re

la_area = pd.read_csv("la.area", sep="\t", dtype=str)
la_area_type = pd.read_csv("la.area_type", sep="\t", dtype=str)

la_series = pd.read_csv(
    "la.series", 
    sep="\t", header=None,
    names=[
        "series_id","area_type_code","area_code",
        "measure_code","seasonal","srd_code",
        "series_title","footnote_codes",
        "begin_year","begin_period",
        "end_year","end_period"
    ],
    dtype=str
)

la_series.head(5)
# Out:
#                         series_id  area_type_code        area_code  \
# 0  series_id                       area_type_code        area_code
# 1  LASBS060000000000003                         L  BS0600000000000
# 2  LASBS060000000000004                         L  BS0600000000000
# 3  LASBS060000000000005                         L  BS0600000000000
# 4  LASBS060000000000006                         L  BS0600000000000
#
#    measure_code  seasonal  srd_code  \
# 0  measure_code  seasonal  srd_code
# 1            03         S        06
# 2            04         S        06
# 3            05         S        06
# 4            06         S        06
#
#                                         series_title  footnote_codes  \
# 0                                       series_title  footnote_codes
# 1  Unemployment Rate: Balance of California, stat...             NaN
# 2  Unemployment: Balance of California, state les...             NaN
# 3  Employment: Balance of California, state less ...             NaN
# 4  Labor Force: Balance of California, state less...             NaN
#
#    begin_year  begin_period  end_year  end_period
# 0  begin_year  begin_period  end_year  end_period
# 1        1976           M01      2025         M02
# 2        1976           M01      2025         M02
# 3        1976           M01      2025         M02
# 4        1976           M01      2025         M02

# %%
# --- 3. Identify Counties for Selected State ---
state_counties = la_area[
    (la_area["area_type_code"] == "F") & 
    (la_area["area_code"].str.startswith("CN" + STATE_FIPS))
].copy()

print(f"Counties found for FIPS {STATE_FIPS}: {len(state_counties)}")
state_counties.head()
# Out:
# Counties found for FIPS 26: 83
#      area_type_code        area_code           area_text display_level  \
# 2444              F  CN2600100000000   Alcona County, MI             0
# 2445              F  CN2600300000000    Alger County, MI             0
# 2446              F  CN2600500000000  Allegan County, MI             0
# 2447              F  CN2600700000000   Alpena County, MI             0
# 2448              F  CN2600900000000   Antrim County, MI             0
#
#      selectable sort_sequence
# 2444          T          3747
# 2445          T          3748
# 2446          T          3749
# 2447          T          3750
# 2448          T          3751

# %%
all_datasets = []

for config in STATE_CONFIGS:
    fips = config["fips"]
    data_file = config["file"]
    state_name = data_file.split(".")[-1]

    
    # Identify counties
    state_counties = la_area[
        (la_area["area_type_code"] == "F") &
        (la_area["area_code"].str.startswith("CN" + fips))
    ].copy()
    
    if state_counties.empty:
        print(f"⚠️ No counties found for {data_file}")
        continue
    
    # Load data
    la_data = pd.read_csv(
        data_file,
        sep="\t", header=None,
        names=["series_id","year","period","value","footnote_codes"],
        dtype=str
    )
    
    # Filter series
    state_series = la_series[la_series["area_code"].isin(state_counties["area_code"])].copy()
    
    # Merge
    merged = (
        la_data
        .merge(state_series, on="series_id")
        .merge(state_counties, on="area_code")
    )
    
    if merged.empty:
        print(f"⚠️ Empty merge for {data_file}")
        continue
    
    merged["year"] = merged["year"].astype(int)
    merged["month"] = merged["period"].str[1:].astype(int)
    merged["value"] = pd.to_numeric(merged["value"], errors="coerce")
    
    # Pivot
    pivoted = merged.pivot_table(
        index=["area_text","year","month"],
        columns="measure_code",
        values="value"
    ).reset_index()
    
    pivoted.rename(columns={
        "03": "unemployment_rate",
        "04": "labor_force",
        "05": "employment",
        "06": "unemployment"
    }, inplace=True)
    
    state_final = pivoted.rename(columns={"area_text": "county"})
    all_datasets.append(state_final)
    
    # Save each state separately
    state_final.to_csv(f"{state_name}_county_employment.csv", index=False)
    print(f"✅ Saved {data_file} with {len(state_final)} rows as {state_name}")
# Out:
# ✅ Saved la.data.7.Alabama with 30552 rows as Alabama
# ✅ Saved la.data.8.Alaska with 12718 rows as Alaska
# ✅ Saved la.data.9.Arizona with 6840 rows as Arizona
# ✅ Saved la.data.10.Arkansas with 34200 rows as Arkansas
# ✅ Saved la.data.11.California with 26449 rows as California
# ✅ Saved la.data.12.Colorado with 29184 rows as Colorado
# ✅ Saved la.data.13.Connecticut with 4104 rows as Connecticut
# ✅ Saved la.data.14.Delaware with 1368 rows as Delaware
# ✅ Saved la.data.15.DC with 457 rows as DC
# ✅ Saved la.data.16.Florida with 30553 rows as Florida
# ✅ Saved la.data.17.Georgia with 72504 rows as Georgia
# ✅ Saved la.data.18.Hawaii with 1824 rows as Hawaii
# ✅ Saved la.data.19.Idaho with 20064 rows as Idaho
# ✅ Saved la.data.20.Illinois with 46512 rows as Illinois
# ✅ Saved la.data.21.Indiana with 41952 rows as Indiana
# ✅ Saved la.data.22.Iowa with 45144 rows as Iowa
# ✅ Saved la.data.23.Kansas with 47880 rows as Kansas
# ✅ Saved la.data.24.Kentucky with 54720 rows as Kentucky
# ✅ Saved la.data.25.Louisiana with 29100 rows as Louisiana
# ✅ Saved la.data.26.Maine with 7296 rows as Maine
# ✅ Saved la.data.27.Maryland with 10944 rows as Maryland
# ✅ Saved la.data.28.Massachusetts with 6384 rows as Massachusetts
# ✅ Saved la.data.29.Michigan with 37848 rows as Michigan
# ✅ Saved la.data.30.Minnesota with 39672 rows as Minnesota
# ✅ Saved la.data.31.Mississippi with 37392 rows as Mississippi
# ✅ Saved la.data.32.Missouri with 52440 rows as Missouri
# ✅ Saved la.data.33.Montana with 25536 rows as Montana
# ✅ Saved la.data.34.Nebraska with 42408 rows as Nebraska
# ✅ Saved la.data.35.Nevada with 7752 rows as Nevada
# ✅ Saved la.data.36.NewHampshire with 4560 rows as NewHampshire
# ✅ Saved la.data.37.NewJersey with 9576 rows as NewJersey
# ✅ Saved la.data.38.NewMexico with 15048 rows as NewMexico
# ✅ Saved la.data.39.NewYork with 28272 rows as NewYork
# ✅ Saved la.data.40.NorthCarolina with 45600 rows as NorthCarolina
# ✅ Saved la.data.41.NorthDakota with 24168 rows as NorthDakota
# ✅ Saved la.data.42.Ohio with 40128 rows as Ohio
# ✅ Saved la.data.43.Oklahoma with 35112 rows as Oklahoma
# ✅ Saved la.data.44.Oregon with 16416 rows as Oregon
# ✅ Saved la.data.45.Pennsylvania with 30552 rows as Pennsylvania
# ✅ Saved la.data.47.RhodeIsland with 2280 rows as RhodeIsland
# ✅ Saved la.data.48.SouthCarolina with 20976 rows as SouthCarolina
# ✅ Saved la.data.49.SouthDakota with 30096 rows as SouthDakota
# ✅ Saved la.data.50.Tennessee with 43320 rows as Tennessee
# ✅ Saved la.data.51.Texas with 115824 rows as Texas
# ✅ Saved la.data.52.Utah with 13224 rows as Utah
# ✅ Saved la.data.53.Vermont with 6384 rows as Vermont
# ✅ Saved la.data.54.Virginia with 60648 rows as Virginia
# ✅ Saved la.data.56.Washington with 17784 rows as Washington
# ✅ Saved la.data.58.Wisconsin with 32832 rows as Wisconsin
# ✅ Saved la.data.59.Wyoming with 10488 rows as Wyoming

# %%
# --- 4. Load State Data File ---
la_data = pd.read_csv(
    DATA_FILE, 
    sep="\t", header=None,
    names=["series_id","year","period","value","footnote_codes"],
    dtype=str
)

print(f"Loaded {DATA_FILE}, rows: {len(la_data)}")
la_data.head()
# Out:
# Loaded la.data.29.Michigan, rows: 406358
#                         series_id  year  period         value  footnote_codes
# 0  series_id                       year  period         value  footnote_codes
# 1  LASBS260000000000003            1990     M01           7.3               S
# 2  LASBS260000000000003            1990     M02           7.2               S
# 3  LASBS260000000000003            1990     M03           7.2               S
# 4  LASBS260000000000003            1990     M04           7.1               S

# %%
# --- 5. Filter Series for State Counties ---
state_series = la_series[la_series["area_code"].isin(state_counties["area_code"])].copy()
print(f"Series found for state: {len(state_series)}")
state_series.head()
# Out:
# Series found for state: 92
#                             series_id area_type_code        area_code  \
# 13683  LAUCN560010000000003                        F  CN5600100000000
# 13684  LAUCN560010000000004                        F  CN5600100000000
# 13685  LAUCN560010000000005                        F  CN5600100000000
# 13686  LAUCN560010000000006                        F  CN5600100000000
# 13687  LAUCN560030000000003                        F  CN5600300000000
#
#       measure_code seasonal srd_code  \
# 13683           03        U       56
# 13684           04        U       56
# 13685           05        U       56
# 13686           06        U       56
# 13687           03        U       56
#
#                                      series_title footnote_codes begin_year  \
# 13683    Unemployment Rate: Albany County, WY (U)            NaN       1990
# 13684         Unemployment: Albany County, WY (U)            NaN       1990
# 13685           Employment: Albany County, WY (U)            NaN       1990
# 13686          Labor Force: Albany County, WY (U)            NaN       1990
# 13687  Unemployment Rate: Big Horn County, WY (U)            NaN       1990
#
#       begin_period end_year end_period
# 13683          M01     2025        M02
# 13684          M01     2025        M02
# 13685          M01     2025        M02
# 13686          M01     2025        M02
# 13687          M01     2025        M02

# %%
# --- 6. Merge Data + Series + Counties ---
merged = (
    la_data
    .merge(state_series, on="series_id")
    .merge(state_counties, on="area_code")
)

merged["year"] = merged["year"].astype(int)
merged["month"] = merged["period"].str[1:].astype(int)
merged["value"] = pd.to_numeric(merged["value"], errors="coerce")

print("Merged dataset:", len(merged), "rows")
merged.head()
# Out:
# Merged dataset: 105796 rows
#                         series_id  year period  value footnote_codes_x  \
# 0  LAUCN060010000000003            1990    M01    3.9              NaN
# 1  LAUCN060010000000003            1990    M02    3.8              NaN
# 2  LAUCN060010000000003            1990    M03    3.6              NaN
# 3  LAUCN060010000000003            1990    M04    3.8              NaN
# 4  LAUCN060010000000003            1990    M05    3.8              NaN
#
#   area_type_code_x        area_code measure_code seasonal srd_code  ...  \
# 0                F  CN0600100000000           03        U       06  ...
# 1                F  CN0600100000000           03        U       06  ...
# 2                F  CN0600100000000           03        U       06  ...
# 3                F  CN0600100000000           03        U       06  ...
# 4                F  CN0600100000000           03        U       06  ...
#
#   begin_year begin_period end_year end_period area_type_code_y  \
# 0       1990          M01     2025        M02                F
# 1       1990          M01     2025        M02                F
# 2       1990          M01     2025        M02                F
# 3       1990          M01     2025        M02                F
# 4       1990          M01     2025        M02                F
#
#             area_text display_level selectable sort_sequence month
# 0  Alameda County, CA             0          T           431     1
# 1  Alameda County, CA             0          T           431     2
# 2  Alameda County, CA             0          T           431     3
# 3  Alameda County, CA             0          T           431     4
# 4  Alameda County, CA             0          T           431     5
#
# [5 rows x 22 columns]

# %%
# --- 7. Pivot to Wide Format ---
pivoted = merged.pivot_table(
    index=["area_text","year","month"],
    columns="measure_code",
    values="value"
).reset_index()

pivoted.rename(columns={
    "03": "unemployment_rate",
    "04": "labor_force",
    "05": "employment",
    "06": "unemployment"
}, inplace=True)

state_final = pivoted.rename(columns={"area_text": "county"})
state_final.head()
# Out:
# measure_code             county  year  month  unemployment_rate  labor_force  \
# 0             Albany County, WY  1990      1                5.6        929.0
# 1             Albany County, WY  1990      2                5.0        842.0
# 2             Albany County, WY  1990      3                5.3        890.0
# 3             Albany County, WY  1990      4                5.5        912.0
# 4             Albany County, WY  1990      5                5.1        828.0
#
# measure_code  employment  unemployment
# 0                15529.0       16458.0
# 1                15983.0       16825.0
# 2                15926.0       16816.0
# 3                15562.0       16474.0
# 4                15370.0       16198.0

# %%
# --- 8. Save Output ---
out_csv = f"state_{STATE_FIPS}_county_employment.csv"
out_xlsx = f"state_{STATE_FIPS}_county_employment.xlsx"

state_final.to_csv(out_csv, index=False)
state_final.to_excel(out_xlsx, index=False)

print(f"✅ Saved {out_csv} and {out_xlsx}")
# Out:
# ✅ Saved state_26_county_employment.csv and state_26_county_employment.xlsx

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
